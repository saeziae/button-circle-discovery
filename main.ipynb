# %% [markdown]
# # 88x31 discovering network (?)
#
# ## how does it work
#
# It detects any `<a>` containing `<img>` and craws the target page to check if there is a link pointing back.

# %%
site = input("Enter a site: ")
if not site.startswith("https://"):
    site = "https://" + site

# %%
from xarxeta import main
r = main(site, 3)
# Out:
# ...
# Depth 3: 100%|██████████| 23/23 [01:17<00:00,  3.38s/site]

# %%
from xarxeta import visualize
visualize(r)
# Out:
# Visualizing relations...
